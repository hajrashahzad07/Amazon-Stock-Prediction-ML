# %%
# numpy and pandas will be used for data manipulation
import numpy as np
import pandas as pd

# matplotlib will be used for visually representing our data
import matplotlib.pyplot as plt

# Yfinance will be used for importing historical oil prices
import yfinance as yfin

# %%
# Setting our ticker
ticker = 'AMZN'
ticker = yfin.Ticker(ticker)

# Importing our data
data = ticker.history(period='5y')

# %%
# Setting the text on the Y-axis
plt.ylabel("Amazon Stock Prices")

# Setting the size of our graph
data['Close'].plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date', ylabel='Amazon Stock Prices'>

# %%
data['MA_20'] = data['Close'].shift(1).rolling(window=20).mean()
data['MA_50']= data['Close'].shift(1).rolling(window=50).mean()
data['EMA_20'] = data['Close'].ewm(span=20, adjust=False).mean()

# %%
data.head(20)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-01-15 00:00:00-05:00  156.151001  157.127502  154.758499  155.212494
# 2021-01-19 00:00:00-05:00  155.350006  157.250000  154.800003  156.037994
# 2021-01-20 00:00:00-05:00  159.099503  163.990005  158.750000  163.169006
# 2021-01-21 00:00:00-05:00  164.649994  167.427505  164.478500  165.349503
# 2021-01-22 00:00:00-05:00  165.215500  166.095505  164.158005  164.611496
# 2021-01-25 00:00:00-05:00  166.425003  168.194504  162.157501  164.699997
# 2021-01-26 00:00:00-05:00  164.817993  166.899994  164.143494  166.306503
# 2021-01-27 00:00:00-05:00  167.074493  167.326004  160.354004  161.628998
# 2021-01-28 00:00:00-05:00  161.751999  165.084000  161.434494  161.880997
# 2021-01-29 00:00:00-05:00  161.500000  161.849503  159.227493  160.309998
# 2021-02-01 00:00:00-05:00  162.117996  167.513000  161.751495  167.143997
# 2021-02-02 00:00:00-05:00  169.000000  171.386993  168.056503  169.000000
# 2021-02-03 00:00:00-05:00  171.250504  171.699997  165.431000  165.626495
# 2021-02-04 00:00:00-05:00  166.500000  167.350006  163.887497  166.550003
# 2021-02-05 00:00:00-05:00  165.949997  168.850006  165.135498  167.607498
# 2021-02-08 00:00:00-05:00  167.925003  168.250000  165.199997  166.147003
# 2021-02-09 00:00:00-05:00  165.624496  166.899994  164.891998  165.250000
# 2021-02-10 00:00:00-05:00  165.699997  165.897507  162.699997  164.328995
# 2021-02-11 00:00:00-05:00  164.600006  164.600006  162.403000  163.106506
# 2021-02-12 00:00:00-05:00  162.500000  164.012497  161.665497  163.885498
#
#                               Volume  Dividends  Stock Splits  MA_20  MA_50  \
# Date
# 2021-01-15 00:00:00-05:00   84880000        0.0           0.0    NaN    NaN
# 2021-01-19 00:00:00-05:00   66102000        0.0           0.0    NaN    NaN
# 2021-01-20 00:00:00-05:00  106196000        0.0           0.0    NaN    NaN
# 2021-01-21 00:00:00-05:00   98722000        0.0           0.0    NaN    NaN
# 2021-01-22 00:00:00-05:00   56438000        0.0           0.0    NaN    NaN
# 2021-01-25 00:00:00-05:00   74996000        0.0           0.0    NaN    NaN
# 2021-01-26 00:00:00-05:00   59104000        0.0           0.0    NaN    NaN
# 2021-01-27 00:00:00-05:00   93204000        0.0           0.0    NaN    NaN
# 2021-01-28 00:00:00-05:00   62984000        0.0           0.0    NaN    NaN
# 2021-01-29 00:00:00-05:00   85872000        0.0           0.0    NaN    NaN
# 2021-02-01 00:00:00-05:00   83204000        0.0           0.0    NaN    NaN
# 2021-02-02 00:00:00-05:00  141972000        0.0           0.0    NaN    NaN
# 2021-02-03 00:00:00-05:00  141776000        0.0           0.0    NaN    NaN
# 2021-02-04 00:00:00-05:00   73414000        0.0           0.0    NaN    NaN
# 2021-02-05 00:00:00-05:00   72416000        0.0           0.0    NaN    NaN
# 2021-02-08 00:00:00-05:00   65148000        0.0           0.0    NaN    NaN
# 2021-02-09 00:00:00-05:00   44070000        0.0           0.0    NaN    NaN
# 2021-02-10 00:00:00-05:00   63032000        0.0           0.0    NaN    NaN
# 2021-02-11 00:00:00-05:00   46028000        0.0           0.0    NaN    NaN
# 2021-02-12 00:00:00-05:00   46706000        0.0           0.0    NaN    NaN
#
#                                EMA_20
# Date
# 2021-01-15 00:00:00-05:00  155.212494
# 2021-01-19 00:00:00-05:00  155.291113
# 2021-01-20 00:00:00-05:00  156.041389
# 2021-01-21 00:00:00-05:00  156.927876
# 2021-01-22 00:00:00-05:00  157.659649
# 2021-01-25 00:00:00-05:00  158.330158
# 2021-01-26 00:00:00-05:00  159.089810
# 2021-01-27 00:00:00-05:00  159.331638
# 2021-01-28 00:00:00-05:00  159.574434
# 2021-01-29 00:00:00-05:00  159.644487
# 2021-02-01 00:00:00-05:00  160.358726
# 2021-02-02 00:00:00-05:00  161.181705
# 2021-02-03 00:00:00-05:00  161.605018
# 2021-02-04 00:00:00-05:00  162.075969
# 2021-02-05 00:00:00-05:00  162.602781
# 2021-02-08 00:00:00-05:00  162.940326
# 2021-02-09 00:00:00-05:00  163.160295
# 2021-02-10 00:00:00-05:00  163.271600
# 2021-02-11 00:00:00-05:00  163.255877
# 2021-02-12 00:00:00-05:00  163.315841

# %%
# Dropping the NaN values
data = data.dropna()

# Initialising X and assigning the two feature variables
X = data[['EMA_20','MA_50']]

# Getting the head of the data
X.head()
# Out:
#                                EMA_20      MA_50
# Date
# 2021-03-30 00:00:00-04:00  154.407339  158.81854
# 2021-03-31 00:00:00-04:00  154.435592  158.76958
# 2021-04-01 00:00:00-04:00  154.779822  158.74290
# 2021-04-05 00:00:00-04:00  155.404268  158.64052
# 2021-04-06 00:00:00-04:00  155.955385  158.56026

# %%
# Dropping the NaN values
data = data.dropna()

# Initialising X and assigning the feature variables
X = data[['MA_20','EMA_20','MA_50', 'Close']]

# Getting the head of the data
X.head()
# Out:
#                                 MA_20      EMA_20      MA_50       Close
# Date
# 2021-03-30 00:00:00-04:00  153.186901  154.407339  158.81854  152.764496
# 2021-03-31 00:00:00-04:00  153.088801  154.435592  158.76958  154.703995
# 2021-04-01 00:00:00-04:00  153.311501  154.779822  158.74290  158.050003
# 2021-04-05 00:00:00-04:00  153.770076  155.404268  158.64052  161.336502
# 2021-04-06 00:00:00-04:00  154.335751  155.955385  158.56026  161.190994

# %%
# Setting the training set to 70% of the data
training = 0.7
t = int(training*len(X))

# Training dataset
data_train= X[:t]

# Testing dataset
data_test = X[t:]

# %%
X[:t]
# Out:
#                                 MA_20      EMA_20       MA_50       Close
# Date
# 2021-03-30 00:00:00-04:00  153.186901  154.407339  158.818540  152.764496
# 2021-03-31 00:00:00-04:00  153.088801  154.435592  158.769580  154.703995
# 2021-04-01 00:00:00-04:00  153.311501  154.779822  158.742900  158.050003
# 2021-04-05 00:00:00-04:00  153.770076  155.404268  158.640520  161.336502
# 2021-04-06 00:00:00-04:00  154.335751  155.955385  158.560260  161.190994
# ...                               ...         ...         ...         ...
# 2024-07-30 00:00:00-04:00  190.932000  186.716476  187.082400  181.710007
# 2024-07-31 00:00:00-04:00  190.157500  186.741573  187.044000  186.979996
# 2024-08-01 00:00:00-04:00  189.506500  186.487138  187.089600  184.070007
# 2024-08-02 00:00:00-04:00  188.830501  184.716934  187.100201  167.899994
# 2024-08-05 00:00:00-04:00  187.225500  182.460083  186.795201  161.020004
#
# [843 rows x 4 columns]

# %%
X[t:]
# Out:
#                                 MA_20      EMA_20       MA_50       Close
# Date
# 2024-08-06 00:00:00-04:00  185.312001  180.504837  186.353000  161.929993
# 2024-08-07 00:00:00-04:00  183.441501  178.815805  185.970600  162.770004
# 2024-08-08 00:00:00-04:00  181.590501  177.576205  185.611000  165.800003
# 2024-08-09 00:00:00-04:00  180.128001  176.563233  185.284001  166.940002
# 2024-08-12 00:00:00-04:00  178.750501  175.633402  184.982401  166.800003
# ...                               ...         ...         ...         ...
# 2026-01-08 00:00:00-05:00  229.979500  233.255365  232.572200  246.289993
# 2026-01-09 00:00:00-05:00  230.898000  234.600569  232.958600  247.380005
# 2026-01-12 00:00:00-05:00  231.678000  235.730991  233.321200  246.470001
# 2026-01-13 00:00:00-05:00  232.487500  236.385183  233.644600  242.600006
# 2026-01-14 00:00:00-05:00  233.308000  236.410403  234.039400  236.649994
#
# [362 rows x 4 columns]

# %%
from pycaret.regression import *
s = setup(
    data=data[['MA_20','MA_50','EMA_20','Close']],
    target='Close',
    session_id=123,
    numeric_features=['MA_20','MA_50','EMA_20'],
    fold_strategy='timeseries', # Ensures temporal integrity
    data_split_shuffle=False,     # Prevents random shuffling
    n_jobs=-1
)
# Out:
# <style type="text/css">
# #T_04db8_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_04db8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04db8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_04db8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04db8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04db8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_04db8_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_04db8_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_04db8_row1_col1" class="data row1 col1" >Close</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_04db8_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_04db8_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_04db8_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_04db8_row3_col1" class="data row3 col1" >(1205, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_04db8_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_04db8_row4_col1" class="data row4 col1" >(1205, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_04db8_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_04db8_row5_col1" class="data row5 col1" >(843, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_04db8_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_04db8_row6_col1" class="data row6 col1" >(362, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_04db8_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_04db8_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_04db8_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_04db8_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_04db8_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_04db8_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_04db8_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_04db8_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_04db8_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_04db8_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_04db8_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_04db8_row12_col1" class="data row12 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_04db8_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_04db8_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_04db8_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_04db8_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_04db8_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_04db8_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_04db8_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_04db8_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_04db8_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_04db8_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_04db8_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_04db8_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_04db8_row18_col1" class="data row18 col1" >1c00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Create a Linear Regression model
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_778c4_row10_col0, #T_778c4_row10_col1, #T_778c4_row10_col2, #T_778c4_row10_col3, #T_778c4_row10_col4, #T_778c4_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_778c4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_778c4_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_778c4_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_778c4_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_778c4_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_778c4_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_778c4_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_778c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_778c4_row0_col0" class="data row0 col0" >2.0009</td>
#       <td id="T_778c4_row0_col1" class="data row0 col1" >7.3227</td>
#       <td id="T_778c4_row0_col2" class="data row0 col2" >2.7060</td>
#       <td id="T_778c4_row0_col3" class="data row0 col3" >0.6976</td>
#       <td id="T_778c4_row0_col4" class="data row0 col4" >0.0157</td>
#       <td id="T_778c4_row0_col5" class="data row0 col5" >0.0118</td>
#     </tr>
#     <tr>
#       <th id="T_778c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_778c4_row1_col0" class="data row1 col0" >3.2209</td>
#       <td id="T_778c4_row1_col1" class="data row1 col1" >17.8931</td>
#       <td id="T_778c4_row1_col2" class="data row1 col2" >4.2300</td>
#       <td id="T_778c4_row1_col3" class="data row1 col3" >0.8687</td>
#       <td id="T_778c4_row1_col4" class="data row1 col4" >0.0271</td>
#       <td id="T_778c4_row1_col5" class="data row1 col5" >0.0205</td>
#     </tr>
#     <tr>
#       <th id="T_778c4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_778c4_row2_col0" class="data row2 col0" >4.5851</td>
#       <td id="T_778c4_row2_col1" class="data row2 col1" >32.3128</td>
#       <td id="T_778c4_row2_col2" class="data row2 col2" >5.6844</td>
#       <td id="T_778c4_row2_col3" class="data row2 col3" >0.9335</td>
#       <td id="T_778c4_row2_col4" class="data row2 col4" >0.0444</td>
#       <td id="T_778c4_row2_col5" class="data row2 col5" >0.0358</td>
#     </tr>
#     <tr>
#       <th id="T_778c4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_778c4_row3_col0" class="data row3 col0" >4.1458</td>
#       <td id="T_778c4_row3_col1" class="data row3 col1" >24.9253</td>
#       <td id="T_778c4_row3_col2" class="data row3 col2" >4.9925</td>
#       <td id="T_778c4_row3_col3" class="data row3 col3" >0.7867</td>
#       <td id="T_778c4_row3_col4" class="data row3 col4" >0.0410</td>
#       <td id="T_778c4_row3_col5" class="data row3 col5" >0.0335</td>
#     </tr>
#     <tr>
#       <th id="T_778c4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_778c4_row4_col0" class="data row4 col0" >2.8882</td>
#       <td id="T_778c4_row4_col1" class="data row4 col1" >14.3983</td>
#       <td id="T_778c4_row4_col2" class="data row4 col2" >3.7945</td>
#       <td id="T_778c4_row4_col3" class="data row4 col3" >0.8542</td>
#       <td id="T_778c4_row4_col4" class="data row4 col4" >0.0387</td>
#       <td id="T_778c4_row4_col5" class="data row4 col5" >0.0301</td>
#     </tr>
#     <tr>
#       <th id="T_778c4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_778c4_row5_col0" class="data row5 col0" >1.5098</td>
#       <td id="T_778c4_row5_col1" class="data row5 col1" >3.7146</td>
#       <td id="T_778c4_row5_col2" class="data row5 col2" >1.9273</td>
#       <td id="T_778c4_row5_col3" class="data row5 col3" >0.8908</td>
#       <td id="T_778c4_row5_col4" class="data row5 col4" >0.0183</td>
#       <td id="T_778c4_row5_col5" class="data row5 col5" >0.0146</td>
#     </tr>
#     <tr>
#       <th id="T_778c4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_778c4_row6_col0" class="data row6 col0" >1.7770</td>
#       <td id="T_778c4_row6_col1" class="data row6 col1" >5.1946</td>
#       <td id="T_778c4_row6_col2" class="data row6 col2" >2.2792</td>
#       <td id="T_778c4_row6_col3" class="data row6 col3" >0.8690</td>
#       <td id="T_778c4_row6_col4" class="data row6 col4" >0.0169</td>
#       <td id="T_778c4_row6_col5" class="data row6 col5" >0.0135</td>
#     </tr>
#     <tr>
#       <th id="T_778c4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_778c4_row7_col0" class="data row7 col0" >2.6031</td>
#       <td id="T_778c4_row7_col1" class="data row7 col1" >10.4264</td>
#       <td id="T_778c4_row7_col2" class="data row7 col2" >3.2290</td>
#       <td id="T_778c4_row7_col3" class="data row7 col3" >0.8760</td>
#       <td id="T_778c4_row7_col4" class="data row7 col4" >0.0241</td>
#       <td id="T_778c4_row7_col5" class="data row7 col5" >0.0193</td>
#     </tr>
#     <tr>
#       <th id="T_778c4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_778c4_row8_col0" class="data row8 col0" >2.0735</td>
#       <td id="T_778c4_row8_col1" class="data row8 col1" >6.3281</td>
#       <td id="T_778c4_row8_col2" class="data row8 col2" >2.5156</td>
#       <td id="T_778c4_row8_col3" class="data row8 col3" >0.9546</td>
#       <td id="T_778c4_row8_col4" class="data row8 col4" >0.0153</td>
#       <td id="T_778c4_row8_col5" class="data row8 col5" >0.0125</td>
#     </tr>
#     <tr>
#       <th id="T_778c4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_778c4_row9_col0" class="data row9 col0" >3.0706</td>
#       <td id="T_778c4_row9_col1" class="data row9 col1" >13.9340</td>
#       <td id="T_778c4_row9_col2" class="data row9 col2" >3.7328</td>
#       <td id="T_778c4_row9_col3" class="data row9 col3" >0.7328</td>
#       <td id="T_778c4_row9_col4" class="data row9 col4" >0.0204</td>
#       <td id="T_778c4_row9_col5" class="data row9 col5" >0.0167</td>
#     </tr>
#     <tr>
#       <th id="T_778c4_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_778c4_row10_col0" class="data row10 col0" >2.7875</td>
#       <td id="T_778c4_row10_col1" class="data row10 col1" >13.6450</td>
#       <td id="T_778c4_row10_col2" class="data row10 col2" >3.5091</td>
#       <td id="T_778c4_row10_col3" class="data row10 col3" >0.8464</td>
#       <td id="T_778c4_row10_col4" class="data row10 col4" >0.0262</td>
#       <td id="T_778c4_row10_col5" class="data row10 col5" >0.0208</td>
#     </tr>
#     <tr>
#       <th id="T_778c4_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_778c4_row11_col0" class="data row11 col0" >0.9576</td>
#       <td id="T_778c4_row11_col1" class="data row11 col1" >8.7654</td>
#       <td id="T_778c4_row11_col2" class="data row11 col2" >1.1536</td>
#       <td id="T_778c4_row11_col3" class="data row11 col3" >0.0786</td>
#       <td id="T_778c4_row11_col4" class="data row11 col4" >0.0106</td>
#       <td id="T_778c4_row11_col5" class="data row11 col5" >0.0086</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
tuned_lr = tune_model(lr)
# Out:
# <style type="text/css">
# #T_855ed_row10_col0, #T_855ed_row10_col1, #T_855ed_row10_col2, #T_855ed_row10_col3, #T_855ed_row10_col4, #T_855ed_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_855ed" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_855ed_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_855ed_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_855ed_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_855ed_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_855ed_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_855ed_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_855ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_855ed_row0_col0" class="data row0 col0" >1.9628</td>
#       <td id="T_855ed_row0_col1" class="data row0 col1" >7.0129</td>
#       <td id="T_855ed_row0_col2" class="data row0 col2" >2.6482</td>
#       <td id="T_855ed_row0_col3" class="data row0 col3" >0.7104</td>
#       <td id="T_855ed_row0_col4" class="data row0 col4" >0.0154</td>
#       <td id="T_855ed_row0_col5" class="data row0 col5" >0.0116</td>
#     </tr>
#     <tr>
#       <th id="T_855ed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_855ed_row1_col0" class="data row1 col0" >3.1773</td>
#       <td id="T_855ed_row1_col1" class="data row1 col1" >17.2000</td>
#       <td id="T_855ed_row1_col2" class="data row1 col2" >4.1473</td>
#       <td id="T_855ed_row1_col3" class="data row1 col3" >0.8738</td>
#       <td id="T_855ed_row1_col4" class="data row1 col4" >0.0266</td>
#       <td id="T_855ed_row1_col5" class="data row1 col5" >0.0202</td>
#     </tr>
#     <tr>
#       <th id="T_855ed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_855ed_row2_col0" class="data row2 col0" >4.2325</td>
#       <td id="T_855ed_row2_col1" class="data row2 col1" >26.8711</td>
#       <td id="T_855ed_row2_col2" class="data row2 col2" >5.1837</td>
#       <td id="T_855ed_row2_col3" class="data row2 col3" >0.9447</td>
#       <td id="T_855ed_row2_col4" class="data row2 col4" >0.0399</td>
#       <td id="T_855ed_row2_col5" class="data row2 col5" >0.0325</td>
#     </tr>
#     <tr>
#       <th id="T_855ed_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_855ed_row3_col0" class="data row3 col0" >3.1770</td>
#       <td id="T_855ed_row3_col1" class="data row3 col1" >15.6333</td>
#       <td id="T_855ed_row3_col2" class="data row3 col2" >3.9539</td>
#       <td id="T_855ed_row3_col3" class="data row3 col3" >0.8662</td>
#       <td id="T_855ed_row3_col4" class="data row3 col4" >0.0323</td>
#       <td id="T_855ed_row3_col5" class="data row3 col5" >0.0259</td>
#     </tr>
#     <tr>
#       <th id="T_855ed_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_855ed_row4_col0" class="data row4 col0" >2.8515</td>
#       <td id="T_855ed_row4_col1" class="data row4 col1" >14.1484</td>
#       <td id="T_855ed_row4_col2" class="data row4 col2" >3.7614</td>
#       <td id="T_855ed_row4_col3" class="data row4 col3" >0.8568</td>
#       <td id="T_855ed_row4_col4" class="data row4 col4" >0.0384</td>
#       <td id="T_855ed_row4_col5" class="data row4 col5" >0.0297</td>
#     </tr>
#     <tr>
#       <th id="T_855ed_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_855ed_row5_col0" class="data row5 col0" >1.4986</td>
#       <td id="T_855ed_row5_col1" class="data row5 col1" >3.6607</td>
#       <td id="T_855ed_row5_col2" class="data row5 col2" >1.9133</td>
#       <td id="T_855ed_row5_col3" class="data row5 col3" >0.8924</td>
#       <td id="T_855ed_row5_col4" class="data row5 col4" >0.0181</td>
#       <td id="T_855ed_row5_col5" class="data row5 col5" >0.0145</td>
#     </tr>
#     <tr>
#       <th id="T_855ed_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_855ed_row6_col0" class="data row6 col0" >1.8018</td>
#       <td id="T_855ed_row6_col1" class="data row6 col1" >5.3196</td>
#       <td id="T_855ed_row6_col2" class="data row6 col2" >2.3064</td>
#       <td id="T_855ed_row6_col3" class="data row6 col3" >0.8658</td>
#       <td id="T_855ed_row6_col4" class="data row6 col4" >0.0171</td>
#       <td id="T_855ed_row6_col5" class="data row6 col5" >0.0136</td>
#     </tr>
#     <tr>
#       <th id="T_855ed_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_855ed_row7_col0" class="data row7 col0" >2.6151</td>
#       <td id="T_855ed_row7_col1" class="data row7 col1" >10.4684</td>
#       <td id="T_855ed_row7_col2" class="data row7 col2" >3.2355</td>
#       <td id="T_855ed_row7_col3" class="data row7 col3" >0.8755</td>
#       <td id="T_855ed_row7_col4" class="data row7 col4" >0.0241</td>
#       <td id="T_855ed_row7_col5" class="data row7 col5" >0.0194</td>
#     </tr>
#     <tr>
#       <th id="T_855ed_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_855ed_row8_col0" class="data row8 col0" >2.0341</td>
#       <td id="T_855ed_row8_col1" class="data row8 col1" >6.1720</td>
#       <td id="T_855ed_row8_col2" class="data row8 col2" >2.4843</td>
#       <td id="T_855ed_row8_col3" class="data row8 col3" >0.9557</td>
#       <td id="T_855ed_row8_col4" class="data row8 col4" >0.0151</td>
#       <td id="T_855ed_row8_col5" class="data row8 col5" >0.0123</td>
#     </tr>
#     <tr>
#       <th id="T_855ed_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_855ed_row9_col0" class="data row9 col0" >3.0746</td>
#       <td id="T_855ed_row9_col1" class="data row9 col1" >13.9750</td>
#       <td id="T_855ed_row9_col2" class="data row9 col2" >3.7383</td>
#       <td id="T_855ed_row9_col3" class="data row9 col3" >0.7320</td>
#       <td id="T_855ed_row9_col4" class="data row9 col4" >0.0204</td>
#       <td id="T_855ed_row9_col5" class="data row9 col5" >0.0167</td>
#     </tr>
#     <tr>
#       <th id="T_855ed_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_855ed_row10_col0" class="data row10 col0" >2.6425</td>
#       <td id="T_855ed_row10_col1" class="data row10 col1" >12.0461</td>
#       <td id="T_855ed_row10_col2" class="data row10 col2" >3.3372</td>
#       <td id="T_855ed_row10_col3" class="data row10 col3" >0.8573</td>
#       <td id="T_855ed_row10_col4" class="data row10 col4" >0.0248</td>
#       <td id="T_855ed_row10_col5" class="data row10 col5" >0.0196</td>
#     </tr>
#     <tr>
#       <th id="T_855ed_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_855ed_row11_col0" class="data row11 col0" >0.7860</td>
#       <td id="T_855ed_row11_col1" class="data row11 col1" >6.6726</td>
#       <td id="T_855ed_row11_col2" class="data row11 col2" >0.9534</td>
#       <td id="T_855ed_row11_col3" class="data row11 col3" >0.0752</td>
#       <td id="T_855ed_row11_col4" class="data row11 col4" >0.0088</td>
#       <td id="T_855ed_row11_col5" class="data row11 col5" >0.0070</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 2 candidates, totalling 20 fits

# %%
models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# gbr             Gradient Boosting Regressor
# mlp                           MLP Regressor
# xgboost           Extreme Gradient Boosting
# lightgbm    Light Gradient Boosting Machine
# dummy                       Dummy Regressor
#
#                                                   Reference  Turbo
# ID
# lr              sklearn.linear_model._base.LinearRegression   True
# lasso        sklearn.linear_model._coordinate_descent.Lasso   True
# ridge                     sklearn.linear_model._ridge.Ridge   True
# en        sklearn.linear_model._coordinate_descent.Elast...   True
# lar                  sklearn.linear_model._least_angle.Lars   True
# llar            sklearn.linear_model._least_angle.LassoLars   True
# omp       sklearn.linear_model._omp.OrthogonalMatchingPu...   True
# br                sklearn.linear_model._bayes.BayesianRidge   True
# ard               sklearn.linear_model._bayes.ARDRegression  False
# par       sklearn.linear_model._passive_aggressive.Passi...   True
# ransac         sklearn.linear_model._ransac.RANSACRegressor  False
# tr        sklearn.linear_model._theil_sen.TheilSenRegressor  False
# huber            sklearn.linear_model._huber.HuberRegressor   True
# kr                         sklearn.kernel_ridge.KernelRidge  False
# svm                                sklearn.svm._classes.SVR  False
# knn       sklearn.neighbors._regression.KNeighborsRegressor   True
# dt              sklearn.tree._classes.DecisionTreeRegressor   True
# rf           sklearn.ensemble._forest.RandomForestRegressor   True
# et             sklearn.ensemble._forest.ExtraTreesRegressor   True
# ada       sklearn.ensemble._weight_boosting.AdaBoostRegr...   True
# gbr          sklearn.ensemble._gb.GradientBoostingRegressor   True
# mlp       sklearn.neural_network._multilayer_perceptron....  False
# xgboost                        xgboost.sklearn.XGBRegressor   True
# lightgbm                     lightgbm.sklearn.LGBMRegressor   True
# dummy                          sklearn.dummy.DummyRegressor   True

# %%
#Define Random Forest Regressor
rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_16f3e_row10_col0, #T_16f3e_row10_col1, #T_16f3e_row10_col2, #T_16f3e_row10_col3, #T_16f3e_row10_col4, #T_16f3e_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_16f3e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16f3e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_16f3e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_16f3e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_16f3e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_16f3e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_16f3e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16f3e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_16f3e_row0_col0" class="data row0 col0" >9.7859</td>
#       <td id="T_16f3e_row0_col1" class="data row0 col1" >125.8691</td>
#       <td id="T_16f3e_row0_col2" class="data row0 col2" >11.2191</td>
#       <td id="T_16f3e_row0_col3" class="data row0 col3" >-4.1976</td>
#       <td id="T_16f3e_row0_col4" class="data row0 col4" >0.0648</td>
#       <td id="T_16f3e_row0_col5" class="data row0 col5" >0.0589</td>
#     </tr>
#     <tr>
#       <th id="T_16f3e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_16f3e_row1_col0" class="data row1 col0" >5.3824</td>
#       <td id="T_16f3e_row1_col1" class="data row1 col1" >68.2794</td>
#       <td id="T_16f3e_row1_col2" class="data row1 col2" >8.2631</td>
#       <td id="T_16f3e_row1_col3" class="data row1 col3" >0.4988</td>
#       <td id="T_16f3e_row1_col4" class="data row1 col4" >0.0531</td>
#       <td id="T_16f3e_row1_col5" class="data row1 col5" >0.0353</td>
#     </tr>
#     <tr>
#       <th id="T_16f3e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_16f3e_row2_col0" class="data row2 col0" >22.2933</td>
#       <td id="T_16f3e_row2_col1" class="data row2 col1" >715.8032</td>
#       <td id="T_16f3e_row2_col2" class="data row2 col2" >26.7545</td>
#       <td id="T_16f3e_row2_col3" class="data row2 col3" >-0.4742</td>
#       <td id="T_16f3e_row2_col4" class="data row2 col4" >0.2038</td>
#       <td id="T_16f3e_row2_col5" class="data row2 col5" >0.1890</td>
#     </tr>
#     <tr>
#       <th id="T_16f3e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_16f3e_row3_col0" class="data row3 col0" >17.1763</td>
#       <td id="T_16f3e_row3_col1" class="data row3 col1" >400.9511</td>
#       <td id="T_16f3e_row3_col2" class="data row3 col2" >20.0238</td>
#       <td id="T_16f3e_row3_col3" class="data row3 col3" >-2.4315</td>
#       <td id="T_16f3e_row3_col4" class="data row3 col4" >0.1646</td>
#       <td id="T_16f3e_row3_col5" class="data row3 col5" >0.1322</td>
#     </tr>
#     <tr>
#       <th id="T_16f3e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_16f3e_row4_col0" class="data row4 col0" >17.0543</td>
#       <td id="T_16f3e_row4_col1" class="data row4 col1" >349.7322</td>
#       <td id="T_16f3e_row4_col2" class="data row4 col2" >18.7011</td>
#       <td id="T_16f3e_row4_col3" class="data row4 col3" >-2.5406</td>
#       <td id="T_16f3e_row4_col4" class="data row4 col4" >0.1847</td>
#       <td id="T_16f3e_row4_col5" class="data row4 col5" >0.1867</td>
#     </tr>
#     <tr>
#       <th id="T_16f3e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_16f3e_row5_col0" class="data row5 col0" >9.7270</td>
#       <td id="T_16f3e_row5_col1" class="data row5 col1" >135.0223</td>
#       <td id="T_16f3e_row5_col2" class="data row5 col2" >11.6199</td>
#       <td id="T_16f3e_row5_col3" class="data row5 col3" >-2.9699</td>
#       <td id="T_16f3e_row5_col4" class="data row5 col4" >0.1168</td>
#       <td id="T_16f3e_row5_col5" class="data row5 col5" >0.0931</td>
#     </tr>
#     <tr>
#       <th id="T_16f3e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_16f3e_row6_col0" class="data row6 col0" >8.0358</td>
#       <td id="T_16f3e_row6_col1" class="data row6 col1" >107.3585</td>
#       <td id="T_16f3e_row6_col2" class="data row6 col2" >10.3614</td>
#       <td id="T_16f3e_row6_col3" class="data row6 col3" >-1.7081</td>
#       <td id="T_16f3e_row6_col4" class="data row6 col4" >0.0804</td>
#       <td id="T_16f3e_row6_col5" class="data row6 col5" >0.0604</td>
#     </tr>
#     <tr>
#       <th id="T_16f3e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_16f3e_row7_col0" class="data row7 col0" >7.5910</td>
#       <td id="T_16f3e_row7_col1" class="data row7 col1" >78.1317</td>
#       <td id="T_16f3e_row7_col2" class="data row7 col2" >8.8392</td>
#       <td id="T_16f3e_row7_col3" class="data row7 col3" >0.0710</td>
#       <td id="T_16f3e_row7_col4" class="data row7 col4" >0.0648</td>
#       <td id="T_16f3e_row7_col5" class="data row7 col5" >0.0544</td>
#     </tr>
#     <tr>
#       <th id="T_16f3e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_16f3e_row8_col0" class="data row8 col0" >5.3274</td>
#       <td id="T_16f3e_row8_col1" class="data row8 col1" >38.0727</td>
#       <td id="T_16f3e_row8_col2" class="data row8 col2" >6.1703</td>
#       <td id="T_16f3e_row8_col3" class="data row8 col3" >0.7269</td>
#       <td id="T_16f3e_row8_col4" class="data row8 col4" >0.0357</td>
#       <td id="T_16f3e_row8_col5" class="data row8 col5" >0.0311</td>
#     </tr>
#     <tr>
#       <th id="T_16f3e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_16f3e_row9_col0" class="data row9 col0" >7.1217</td>
#       <td id="T_16f3e_row9_col1" class="data row9 col1" >84.6397</td>
#       <td id="T_16f3e_row9_col2" class="data row9 col2" >9.2000</td>
#       <td id="T_16f3e_row9_col3" class="data row9 col3" >-0.6230</td>
#       <td id="T_16f3e_row9_col4" class="data row9 col4" >0.0494</td>
#       <td id="T_16f3e_row9_col5" class="data row9 col5" >0.0378</td>
#     </tr>
#     <tr>
#       <th id="T_16f3e_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_16f3e_row10_col0" class="data row10 col0" >10.9495</td>
#       <td id="T_16f3e_row10_col1" class="data row10 col1" >210.3860</td>
#       <td id="T_16f3e_row10_col2" class="data row10 col2" >13.1152</td>
#       <td id="T_16f3e_row10_col3" class="data row10 col3" >-1.3648</td>
#       <td id="T_16f3e_row10_col4" class="data row10 col4" >0.1018</td>
#       <td id="T_16f3e_row10_col5" class="data row10 col5" >0.0879</td>
#     </tr>
#     <tr>
#       <th id="T_16f3e_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_16f3e_row11_col0" class="data row11 col0" >5.5190</td>
#       <td id="T_16f3e_row11_col1" class="data row11 col1" >204.4030</td>
#       <td id="T_16f3e_row11_col2" class="data row11 col2" >6.1949</td>
#       <td id="T_16f3e_row11_col3" class="data row11 col3" >1.5650</td>
#       <td id="T_16f3e_row11_col4" class="data row11 col4" >0.0584</td>
#       <td id="T_16f3e_row11_col5" class="data row11 col5" >0.0576</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
#Train & Test Random Forest Regressor
tuned_rf = tune_model(rf)
# Out:
# <style type="text/css">
# #T_422d2_row10_col0, #T_422d2_row10_col1, #T_422d2_row10_col2, #T_422d2_row10_col3, #T_422d2_row10_col4, #T_422d2_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_422d2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_422d2_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_422d2_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_422d2_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_422d2_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_422d2_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_422d2_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_422d2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_422d2_row0_col0" class="data row0 col0" >8.8992</td>
#       <td id="T_422d2_row0_col1" class="data row0 col1" >110.9444</td>
#       <td id="T_422d2_row0_col2" class="data row0 col2" >10.5330</td>
#       <td id="T_422d2_row0_col3" class="data row0 col3" >-3.5813</td>
#       <td id="T_422d2_row0_col4" class="data row0 col4" >0.0609</td>
#       <td id="T_422d2_row0_col5" class="data row0 col5" >0.0536</td>
#     </tr>
#     <tr>
#       <th id="T_422d2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_422d2_row1_col0" class="data row1 col0" >6.5590</td>
#       <td id="T_422d2_row1_col1" class="data row1 col1" >97.3363</td>
#       <td id="T_422d2_row1_col2" class="data row1 col2" >9.8659</td>
#       <td id="T_422d2_row1_col3" class="data row1 col3" >0.2855</td>
#       <td id="T_422d2_row1_col4" class="data row1 col4" >0.0628</td>
#       <td id="T_422d2_row1_col5" class="data row1 col5" >0.0431</td>
#     </tr>
#     <tr>
#       <th id="T_422d2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_422d2_row2_col0" class="data row2 col0" >22.6564</td>
#       <td id="T_422d2_row2_col1" class="data row2 col1" >778.7325</td>
#       <td id="T_422d2_row2_col2" class="data row2 col2" >27.9058</td>
#       <td id="T_422d2_row2_col3" class="data row2 col3" >-0.6038</td>
#       <td id="T_422d2_row2_col4" class="data row2 col4" >0.2118</td>
#       <td id="T_422d2_row2_col5" class="data row2 col5" >0.1938</td>
#     </tr>
#     <tr>
#       <th id="T_422d2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_422d2_row3_col0" class="data row3 col0" >15.4235</td>
#       <td id="T_422d2_row3_col1" class="data row3 col1" >353.9802</td>
#       <td id="T_422d2_row3_col2" class="data row3 col2" >18.8144</td>
#       <td id="T_422d2_row3_col3" class="data row3 col3" >-2.0295</td>
#       <td id="T_422d2_row3_col4" class="data row3 col4" >0.1534</td>
#       <td id="T_422d2_row3_col5" class="data row3 col5" >0.1175</td>
#     </tr>
#     <tr>
#       <th id="T_422d2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_422d2_row4_col0" class="data row4 col0" >18.6391</td>
#       <td id="T_422d2_row4_col1" class="data row4 col1" >420.1937</td>
#       <td id="T_422d2_row4_col2" class="data row4 col2" >20.4986</td>
#       <td id="T_422d2_row4_col3" class="data row4 col3" >-3.2539</td>
#       <td id="T_422d2_row4_col4" class="data row4 col4" >0.2005</td>
#       <td id="T_422d2_row4_col5" class="data row4 col5" >0.2045</td>
#     </tr>
#     <tr>
#       <th id="T_422d2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_422d2_row5_col0" class="data row5 col0" >8.7116</td>
#       <td id="T_422d2_row5_col1" class="data row5 col1" >109.1877</td>
#       <td id="T_422d2_row5_col2" class="data row5 col2" >10.4493</td>
#       <td id="T_422d2_row5_col3" class="data row5 col3" >-2.2103</td>
#       <td id="T_422d2_row5_col4" class="data row5 col4" >0.1038</td>
#       <td id="T_422d2_row5_col5" class="data row5 col5" >0.0832</td>
#     </tr>
#     <tr>
#       <th id="T_422d2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_422d2_row6_col0" class="data row6 col0" >6.0240</td>
#       <td id="T_422d2_row6_col1" class="data row6 col1" >54.3857</td>
#       <td id="T_422d2_row6_col2" class="data row6 col2" >7.3747</td>
#       <td id="T_422d2_row6_col3" class="data row6 col3" >-0.3719</td>
#       <td id="T_422d2_row6_col4" class="data row6 col4" >0.0569</td>
#       <td id="T_422d2_row6_col5" class="data row6 col5" >0.0457</td>
#     </tr>
#     <tr>
#       <th id="T_422d2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_422d2_row7_col0" class="data row7 col0" >9.0169</td>
#       <td id="T_422d2_row7_col1" class="data row7 col1" >112.7902</td>
#       <td id="T_422d2_row7_col2" class="data row7 col2" >10.6203</td>
#       <td id="T_422d2_row7_col3" class="data row7 col3" >-0.3411</td>
#       <td id="T_422d2_row7_col4" class="data row7 col4" >0.0760</td>
#       <td id="T_422d2_row7_col5" class="data row7 col5" >0.0632</td>
#     </tr>
#     <tr>
#       <th id="T_422d2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_422d2_row8_col0" class="data row8 col0" >6.5444</td>
#       <td id="T_422d2_row8_col1" class="data row8 col1" >61.3823</td>
#       <td id="T_422d2_row8_col2" class="data row8 col2" >7.8347</td>
#       <td id="T_422d2_row8_col3" class="data row8 col3" >0.5598</td>
#       <td id="T_422d2_row8_col4" class="data row8 col4" >0.0468</td>
#       <td id="T_422d2_row8_col5" class="data row8 col5" >0.0385</td>
#     </tr>
#     <tr>
#       <th id="T_422d2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_422d2_row9_col0" class="data row9 col0" >5.8076</td>
#       <td id="T_422d2_row9_col1" class="data row9 col1" >62.6515</td>
#       <td id="T_422d2_row9_col2" class="data row9 col2" >7.9153</td>
#       <td id="T_422d2_row9_col3" class="data row9 col3" >-0.2014</td>
#       <td id="T_422d2_row9_col4" class="data row9 col4" >0.0424</td>
#       <td id="T_422d2_row9_col5" class="data row9 col5" >0.0309</td>
#     </tr>
#     <tr>
#       <th id="T_422d2_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_422d2_row10_col0" class="data row10 col0" >10.8282</td>
#       <td id="T_422d2_row10_col1" class="data row10 col1" >216.1585</td>
#       <td id="T_422d2_row10_col2" class="data row10 col2" >13.1812</td>
#       <td id="T_422d2_row10_col3" class="data row10 col3" >-1.1748</td>
#       <td id="T_422d2_row10_col4" class="data row10 col4" >0.1015</td>
#       <td id="T_422d2_row10_col5" class="data row10 col5" >0.0874</td>
#     </tr>
#     <tr>
#       <th id="T_422d2_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_422d2_row11_col0" class="data row11 col0" >5.6425</td>
#       <td id="T_422d2_row11_col1" class="data row11 col1" >223.1864</td>
#       <td id="T_422d2_row11_col2" class="data row11 col2" >6.5127</td>
#       <td id="T_422d2_row11_col3" class="data row11 col3" >1.4025</td>
#       <td id="T_422d2_row11_col4" class="data row11 col4" >0.0608</td>
#       <td id="T_422d2_row11_col5" class="data row11 col5" >0.0608</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
print(tuned_rf)
# Out:
# RandomForestRegressor(max_depth=6, max_features='log2',
#                       min_impurity_decrease=0.0002, min_samples_leaf=2,
#                       n_estimators=290, n_jobs=-1, random_state=123)

# %%
plot_model(tuned_rf)

# %%
plot_model(tuned_rf, plot = 'error')

# %%
plot_model(tuned_rf, plot = 'feature')

# %%
evaluate_model(tuned_rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(tuned_rf)
# Out:
# <style type="text/css">
# </style>
# <table id="T_dc2a9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc2a9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_dc2a9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_dc2a9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_dc2a9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_dc2a9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_dc2a9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_dc2a9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc2a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dc2a9_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_dc2a9_row0_col1" class="data row0 col1" >26.3861</td>
#       <td id="T_dc2a9_row0_col2" class="data row0 col2" >978.2077</td>
#       <td id="T_dc2a9_row0_col3" class="data row0 col3" >31.2763</td>
#       <td id="T_dc2a9_row0_col4" class="data row0 col4" >-1.2981</td>
#       <td id="T_dc2a9_row0_col5" class="data row0 col5" >0.1500</td>
#       <td id="T_dc2a9_row0_col6" class="data row0 col6" >0.1183</td>
#     </tr>
#   </tbody>
# </table>
#                                 MA_20       MA_50      EMA_20       Close  \
# Date
# 2024-08-06 00:00:00-04:00  185.311996  186.352997  180.504837  161.929993
# 2024-08-07 00:00:00-04:00  183.441498  185.970596  178.815811  162.770004
# 2024-08-08 00:00:00-04:00  181.590500  185.611008  177.576202  165.800003
# 2024-08-09 00:00:00-04:00  180.128006  185.283997  176.563232  166.940002
# 2024-08-12 00:00:00-04:00  178.750504  184.982407  175.633408  166.800003
# ...                               ...         ...         ...         ...
# 2026-01-08 00:00:00-05:00  229.979492  232.572205  233.255371  246.289993
# 2026-01-09 00:00:00-05:00  230.897995  232.958603  234.600571  247.380005
# 2026-01-12 00:00:00-05:00  231.677994  233.321198  235.730988  246.470001
# 2026-01-13 00:00:00-05:00  232.487503  233.644608  236.385178  242.600006
# 2026-01-14 00:00:00-05:00  233.307999  234.039398  236.410400  236.649994
#
#                            prediction_label
# Date
# 2024-08-06 00:00:00-04:00        183.074526
# 2024-08-07 00:00:00-04:00        182.447377
# 2024-08-08 00:00:00-04:00        180.874841
# 2024-08-09 00:00:00-04:00        180.497931
# 2024-08-12 00:00:00-04:00        180.242966
# ...                                     ...
# 2026-01-08 00:00:00-05:00        187.909710
# 2026-01-09 00:00:00-05:00        187.909710
# 2026-01-12 00:00:00-05:00        187.909710
# 2026-01-13 00:00:00-05:00        187.909710
# 2026-01-14 00:00:00-05:00        187.909710
#
# [362 rows x 5 columns]

# %%
final_rf = finalize_model(tuned_rf)

# %%
print(final_rf)
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['MA_20', 'MA_50', 'EMA_20'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('actual_estimator',
#                  RandomForestRegressor(max_depth=6, max_features='log2',
#                                        min_impurity_decrease=0.0002,
#                                        min_samples_leaf=2, n_estimators=290,
#                                        n_jobs=-1, random_state=123))])

# %%
predict_model(final_rf)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3e3ba" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e3ba_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3e3ba_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3e3ba_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3e3ba_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3e3ba_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3e3ba_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3e3ba_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e3ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3e3ba_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_3e3ba_row0_col1" class="data row0 col1" >4.5216</td>
#       <td id="T_3e3ba_row0_col2" class="data row0 col2" >36.7276</td>
#       <td id="T_3e3ba_row0_col3" class="data row0 col3" >6.0603</td>
#       <td id="T_3e3ba_row0_col4" class="data row0 col4" >0.9137</td>
#       <td id="T_3e3ba_row0_col5" class="data row0 col5" >0.0287</td>
#       <td id="T_3e3ba_row0_col6" class="data row0 col6" >0.0215</td>
#     </tr>
#   </tbody>
# </table>
#                                 MA_20       MA_50      EMA_20       Close  \
# Date
# 2024-08-06 00:00:00-04:00  185.311996  186.352997  180.504837  161.929993
# 2024-08-07 00:00:00-04:00  183.441498  185.970596  178.815811  162.770004
# 2024-08-08 00:00:00-04:00  181.590500  185.611008  177.576202  165.800003
# 2024-08-09 00:00:00-04:00  180.128006  185.283997  176.563232  166.940002
# 2024-08-12 00:00:00-04:00  178.750504  184.982407  175.633408  166.800003
# ...                               ...         ...         ...         ...
# 2026-01-08 00:00:00-05:00  229.979492  232.572205  233.255371  246.289993
# 2026-01-09 00:00:00-05:00  230.897995  232.958603  234.600571  247.380005
# 2026-01-12 00:00:00-05:00  231.677994  233.321198  235.730988  246.470001
# 2026-01-13 00:00:00-05:00  232.487503  233.644608  236.385178  242.600006
# 2026-01-14 00:00:00-05:00  233.307999  234.039398  236.410400  236.649994
#
#                            prediction_label
# Date
# 2024-08-06 00:00:00-04:00        178.433742
# 2024-08-07 00:00:00-04:00        177.714923
# 2024-08-08 00:00:00-04:00        176.108735
# 2024-08-09 00:00:00-04:00        176.078698
# 2024-08-12 00:00:00-04:00        175.668577
# ...                                     ...
# 2026-01-08 00:00:00-05:00        240.769931
# 2026-01-09 00:00:00-05:00        241.159785
# 2026-01-12 00:00:00-05:00        240.729595
# 2026-01-13 00:00:00-05:00        239.650490
# 2026-01-14 00:00:00-05:00        239.305091
#
# [362 rows x 5 columns]

# %%
unseenrf_predictions = predict_model(final_rf, data=data_test)
unseenrf_predictions
# Out:
# <style type="text/css">
# </style>
# <table id="T_768fc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_768fc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_768fc_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_768fc_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_768fc_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_768fc_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_768fc_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_768fc_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_768fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_768fc_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_768fc_row0_col1" class="data row0 col1" >4.5216</td>
#       <td id="T_768fc_row0_col2" class="data row0 col2" >36.7276</td>
#       <td id="T_768fc_row0_col3" class="data row0 col3" >6.0603</td>
#       <td id="T_768fc_row0_col4" class="data row0 col4" >0.9137</td>
#       <td id="T_768fc_row0_col5" class="data row0 col5" >0.0287</td>
#       <td id="T_768fc_row0_col6" class="data row0 col6" >0.0215</td>
#     </tr>
#   </tbody>
# </table>
#                                 MA_20      EMA_20       MA_50       Close  \
# Date
# 2024-08-06 00:00:00-04:00  185.311996  180.504837  186.352997  161.929993
# 2024-08-07 00:00:00-04:00  183.441498  178.815811  185.970596  162.770004
# 2024-08-08 00:00:00-04:00  181.590500  177.576202  185.611008  165.800003
# 2024-08-09 00:00:00-04:00  180.128006  176.563232  185.283997  166.940002
# 2024-08-12 00:00:00-04:00  178.750504  175.633408  184.982407  166.800003
# ...                               ...         ...         ...         ...
# 2026-01-08 00:00:00-05:00  229.979492  233.255371  232.572205  246.289993
# 2026-01-09 00:00:00-05:00  230.897995  234.600571  232.958603  247.380005
# 2026-01-12 00:00:00-05:00  231.677994  235.730988  233.321198  246.470001
# 2026-01-13 00:00:00-05:00  232.487503  236.385178  233.644608  242.600006
# 2026-01-14 00:00:00-05:00  233.307999  236.410400  234.039398  236.649994
#
#                            prediction_label
# Date
# 2024-08-06 00:00:00-04:00        178.433742
# 2024-08-07 00:00:00-04:00        177.714923
# 2024-08-08 00:00:00-04:00        176.108735
# 2024-08-09 00:00:00-04:00        176.078698
# 2024-08-12 00:00:00-04:00        175.668577
# ...                                     ...
# 2026-01-08 00:00:00-05:00        240.769931
# 2026-01-09 00:00:00-05:00        241.159785
# 2026-01-12 00:00:00-05:00        240.729595
# 2026-01-13 00:00:00-05:00        239.650490
# 2026-01-14 00:00:00-05:00        239.305091
#
# [362 rows x 5 columns]

# %%
#Visualise Random Forest Regressor
predictedrf_price = pd.DataFrame(unseenrf_predictions,index=unseenrf_predictions.index,columns = ['prediction_label'])
predictedrf_price.plot(figsize=(10,5))
unseenrf_predictions['Close'].plot()
plt.legend(['Predicted Price','Actual Price'])
plt.ylabel("Amazon Stock Prices")
plt.show()

#Comparison of performance against Linear Regression Model - See Cwk Documentation
